# %%
import os

import logging
logging.basicConfig(level=logging.INFO)

import cudf
import dask_cudf
import nvtabular as nvt
from nvtabular import dataset as ds

# %%
dataset = ds.ClothingReviews("/romeyn/data")

data = dataset.transform(for_training=True)
stats = dataset.statistics(transformed=False)

stats.display_overview()
# Out:
# INFO:nvtabular:Preparing data...
# INFO:numba.cuda.cudadrv.driver:init
# INFO:nvtabular:Transforming dataset...
# INFO:nvtabular:Fitting dataset...
# ['Division Name', 'Department Name', 'Class Name', 'Clothing ID']
# ['Positive Feedback Count', 'Age']
# fit
# ['Positive Feedback Count', 'Age']
# Department Name            object
# Title                      object
# Review Text                object
# Class Name                 object
# Age                         int64
# Division Name              object
# Recommended IND             int64
# Rating                      int64
# Positive Feedback Count     int64
# Clothing ID                 int64
# dtype: object
# ['Recommended', 'Rating', 'Positive Feedback Count', 'Age', 'Division Name', 'Department Name', 'Class Name', 'Clothing ID', 'Title', 'Review Text']
# INFO:nvtabular:Transforming train...
# INFO:nvtabular:Transforming eval...
# INFO:nvtabular:Saving to /romeyn/data/clothing_reviews/transformed/ce06e0a35c2d346230f566b5402cc4a4_60ed76f95bf5241d36dcbabe253501c1
# INFO:nvtabular:Saving dataset to parquet in: /romeyn/data/clothing_reviews/transformed/ce06e0a35c2d346230f566b5402cc4a4_60ed76f95bf5241d36dcbabe253501c1
# ['Recommended', 'Rating', 'Positive Feedback Count', 'Age', 'Division Name', 'Department Name', 'Class Name', 'Clothing ID', 'Title', 'Review Text']
# ['Recommended', 'Rating', 'Positive Feedback Count', 'Age', 'Division Name', 'Department Name', 'Class Name', 'Clothing ID', 'Title', 'Review Text']
# INFO:nvtabular:Saving to /romeyn/data/clothing_reviews/transformed/fe3f7737b84fe8ff3216954796bc0408_60ed76f95bf5241d36dcbabe253501c1
# INFO:nvtabular:Saving dataset to parquet in: /romeyn/data/clothing_reviews/transformed/fe3f7737b84fe8ff3216954796bc0408_60ed76f95bf5241d36dcbabe253501c1
# ['Recommended', 'Rating', 'Positive Feedback Count', 'Age', 'Division Name', 'Department Name', 'Class Name', 'Clothing ID', 'Title', 'Review Text']
# Department Name              int64
# Title                       object
# Age                        float32
# Class Name                   int64
# Review Text                 object
# Division Name                int64
# Rating                       int64
# Positive Feedback Count    float32
# Clothing ID                  int64
# Recommended                  int64
# dtype: object
# ['Recommended', 'Rating', 'Positive Feedback Count', 'Age', 'Division Name', 'Department Name', 'Class Name', 'Clothing ID', 'Title', 'Review Text']
# ['Recommended', 'Rating', 'Positive Feedback Count', 'Age', 'Division Name', 'Department Name', 'Class Name', 'Clothing ID', 'Title', 'Review Text']
# Department Name              int64
# Title                       object
# Review Text                 object
# Age                        float32
# Class Name                   int64
# Division Name                int64
# Rating                       int64
# Positive Feedback Count    float32
# Clothing ID                  int64
# Recommended                  int64
# dtype: object
# ['Recommended', 'Rating', 'Positive Feedback Count', 'Age', 'Division Name', 'Department Name', 'Class Name', 'Clothing ID', 'Title', 'Review Text']
# INFO:nvtabular:Preparing data...
# ['Unnamed: 0', 'Clothing ID', 'Age', 'Title', 'Review Text', 'Rating', 'Recommended IND', 'Positive Feedback Count', 'Division Name', 'Department Name', 'Class Name']
# Department Name            object
# Title                      object
# Review Text                object
# Age                         int64
# Class Name                 object
# Division Name              object
# Recommended IND             int64
# Rating                      int64
# Positive Feedback Count     int64
# Unnamed: 0                  int64
# Clothing ID                 int64
# dtype: object
# ['Unnamed: 0', 'Clothing ID', 'Age', 'Title', 'Review Text', 'Rating', 'Recommended IND', 'Positive Feedback Count', 'Division Name', 'Department Name', 'Class Name']
# ['Unnamed: 0', 'Clothing ID', 'Age', 'Title', 'Review Text', 'Rating', 'Recommended IND', 'Positive Feedback Count', 'Division Name', 'Department Name', 'Class Name']
# Department Name            object
# Title                      object
# Review Text                object
# Age                         int64
# Class Name                 object
# Division Name              object
# Recommended IND             int64
# Rating                      int64
# Positive Feedback Count     int64
# Unnamed: 0                  int64
# Clothing ID                 int64
# dtype: object
# ['Unnamed: 0', 'Clothing ID', 'Age', 'Title', 'Review Text', 'Rating', 'Recommended IND', 'Positive Feedback Count', 'Division Name', 'Department Name', 'Class Name']
# <script src="https://cdnjs.cloudflare.com/ajax/libs/webcomponentsjs/1.3.3/webcomponents-lite.js"></script>
# <link rel="import" href="https://raw.githubusercontent.com/PAIR-code/facets/1.0.0/facets-dist/facets-jupyter.html" >
# <facets-overview id="elem"></facets-overview>
# <script>
#  document.querySelector("#elem").protoInput = "...";
# </script>

# %%
os.environ["TF_MEMORY_ALLOCATION"] = "0.7"

import tensorflow as tf
from merlin_models import tf as mtf
# Out:
# INFO:numba.cuda.cudadrv.driver:init

# %%
batch_size = 10000

train_data = mtf.DataLoader.from_directory(data.train, batch_size=batch_size)
eval_data = mtf.DataLoader.from_directory(data.eval, batch_size=batch_size)

# %%
train_data.schema
# Out:
# feature {
#   name: "Recommended"
#   type: INT
#   int_domain {
#     name: "Recommended"
#     min: 0
#     max: 1
#     is_categorical: false
#   }
#   annotation {
#     tag: "binary"
#     tag: "target"
#   }
# }
# feature {
#   name: "Rating"
#   type: INT
#   int_domain {
#     name: "Rating"
#     min: 1
#     max: 5
#     is_categorical: false
#   }
#   annotation {
#     tag: "regression"
#     tag: "target"
#   }
# }
# feature {
#   name: "Positive Feedback Count"
#   type: FLOAT
#   float_domain {
#     name: "Positive Feedback Count"
#     min: -0.4472583
#     max: 20.985716
#   }
#   annotation {
#     tag: "continuous"
#   }
# }
# feature {
#   name: "Age"
#   type: FLOAT
#   float_domain {
#     name: "Age"
#     min: -2.0518227
#     max: 4.54904
#   }
#   annotation {
#     tag: "continuous"
#   }
# }
# feature {
#   name: "Division Name"
#   type: INT
#   int_domain {
#     name: "Division Name"
#     min: 0
#     max: 3
#     is_categorical: true
#   }
#   annotation {
#     tag: "categorical"
#   }
# }
# feature {
#   name: "Department Name"
#   type: INT
#   int_domain {
#     name: "Department Name"
#     min: 0
#     max: 6
#     is_categorical: true
#   }
#   annotation {
#     tag: "categorical"
#   }
# }
# feature {
#   name: "Class Name"
#   type: INT
#   int_domain {
#     name: "Class Name"
#     min: 0
#     max: 20
#     is_categorical: true
#   }
#   annotation {
#     tag: "categorical"
#   }
# }
# feature {
#   name: "Clothing ID"
#   type: INT
#   int_domain {
#     name: "Clothing ID"
#     min: 1
#     max: 1150
#     is_categorical: true
#   }
#   annotation {
#     tag: "categorical"
#   }
# }
# feature {
#   name: "Title"
#   annotation {
#     tag: "text"
#   }
# }
# feature {
#   name: "Review Text"
#   annotation {
#     tag: "text"
#   }
# }

# %%
train_data.columns.embedding_sizes()
# Out:
# {'Division Name': (3, 16),
#  'Department Name': (6, 16),
#  'Class Name': (20, 16),
#  'Clothing ID': (1150, 83)}

# %%
bottom_mlp = mtf.MLPBlock([64, 16])
top_mlp = mtf.MLPBlock([256, 128, 64])
dlrm_block = mtf.DLRMBlock.from_column_group(train_data.columns, bottom_mlp, top_mlp=top_mlp)

head = mtf.Head.from_column_group(train_data.columns)
model = dlrm_block.to_model(head=head, optimizer="adam", run_eagerly=True)

model
# Out:
# DLRMBlockWithHead(
#   (block): DLRMBlock(
#     (stack_features): MergeTabular(
#       (to_merge): List(
#         (0): EmbeddingFeatures(
#           (convert_to_sparse): AsSparseFeatures()
#           (embeddings): Dict(
#             (Division Name): TableConfig(vocabulary_size=3, dim=16, initializer=None, optimizer=None, combiner='mean', name='Division Name')
#             (Department Name): TableConfig(vocabulary_size=6, dim=16, initializer=None, optimizer=None, combiner='mean', name='Department Name')
#             (Class Name): TableConfig(vocabulary_size=20, dim=16, initializer=None, optimizer=None, combiner='mean', name='Class Name')
#             (Clothing ID): TableConfig(vocabulary_size=1150, dim=16, initializer=None, optimizer=None, combiner='mean', name='Clothing ID')
#           )
#         )
#         (1): ContinuousEmbedding(
#           (layers): List(
#             (0): ContinuousFeatures(
#               Age, Positive Feedback Count
#               (aggregation): ConcatFeatures()
#             )
#             (1): Dense(64, activation=relu, use_bias=True)
#             (2): Dense(16, activation=relu, use_bias=True)
#             (3): ExpandDimsAndToTabular()
#           )
#         )
#       )
#       (aggregation): StackFeatures()
#     )
#     (interaction_layer): DotProductInteraction()
#     (top_mlp): MLPBlock(
#       (layers): List(
#         (0): Dense(256, activation=relu, use_bias=True)
#         (1): Dense(128, activation=relu, use_bias=True)
#         (2): Dense(64, activation=relu, use_bias=True)
#       )
#     )
#   )
#   (head): Head(
#     (tasks): Dict(
#       (Recommended): PredictionTask(
#         (pre): Dense(1, activation=sigmoid, use_bias=True)
#         (eval_metrics): List(
#           (0): Precision()
#           (1): Recall()
#           (2): BinaryAccuracy()
#           (3): AUC()
#         )
#         (loss): BinaryCrossentropy()
#       )
#       (Rating): PredictionTask(
#         (pre): Dense(1, activation=linear, use_bias=True)
#         (eval_metrics): List(
#           (0): RootMeanSquaredError()
#         )
#         (loss): MeanSquaredError()
#       )
#     )
#   )
#   (optimizer): Adam()
# )

# %%
model.fit(train_data, epochs=10)
# Out:
# Epoch 1/10
# 3/3 [==============================] - 0s 86ms/step - Rating/rmse: 4.3489 - Recommended/precision: 0.8173 - Recommended/recall: 0.3040 - Recommended/accuracy: 0.3704 - Recommended/auc: 0.4939 - loss: 19.2877 - regularization_loss: 0.0000e+00 - total_loss: 19.2877
# Epoch 2/10
# 3/3 [==============================] - 0s 85ms/step - Rating/rmse: 4.1638 - Recommended/precision: 0.8227 - Recommended/recall: 0.2108 - Recommended/accuracy: 0.3122 - Recommended/auc: 0.4949 - loss: 17.6441 - regularization_loss: 0.0000e+00 - total_loss: 17.6441
# Epoch 3/10
# 3/3 [==============================] - 0s 88ms/step - Rating/rmse: 3.9116 - Recommended/precision: 0.8251 - Recommended/recall: 0.2601 - Recommended/accuracy: 0.3448 - Recommended/auc: 0.4965 - loss: 15.4331 - regularization_loss: 0.0000e+00 - total_loss: 15.4331
# Epoch 4/10
# 3/3 [==============================] - 0s 83ms/step - Rating/rmse: 3.5410 - Recommended/precision: 0.8260 - Recommended/recall: 0.5658 - Recommended/accuracy: 0.5440 - Recommended/auc: 0.4932 - loss: 12.4711 - regularization_loss: 0.0000e+00 - total_loss: 12.4711
# Epoch 5/10
# 3/3 [==============================] - 0s 79ms/step - Rating/rmse: 3.0147 - Recommended/precision: 0.8251 - Recommended/recall: 0.9329 - Recommended/accuracy: 0.7817 - Recommended/auc: 0.4938 - loss: 8.8230 - regularization_loss: 0.0000e+00 - total_loss: 8.8230
# Epoch 6/10
# 3/3 [==============================] - 0s 89ms/step - Rating/rmse: 2.2837 - Recommended/precision: 0.8241 - Recommended/recall: 1.0000 - Recommended/accuracy: 0.8241 - Recommended/auc: 0.4887 - loss: 4.9554 - regularization_loss: 0.0000e+00 - total_loss: 4.9554
# Epoch 7/10
# 3/3 [==============================] - 0s 83ms/step - Rating/rmse: 1.5374 - Recommended/precision: 0.8241 - Recommended/recall: 1.0000 - Recommended/accuracy: 0.8241 - Recommended/auc: 0.4913 - loss: 2.7044 - regularization_loss: 0.0000e+00 - total_loss: 2.7044
# Epoch 8/10
# 3/3 [==============================] - 0s 87ms/step - Rating/rmse: 1.6648 - Recommended/precision: 0.8241 - Recommended/recall: 1.0000 - Recommended/accuracy: 0.8241 - Recommended/auc: 0.4893 - loss: 3.5075 - regularization_loss: 0.0000e+00 - total_loss: 3.5075
# Epoch 9/10
# 3/3 [==============================] - 0s 83ms/step - Rating/rmse: 1.7797 - Recommended/precision: 0.8241 - Recommended/recall: 1.0000 - Recommended/accuracy: 0.8241 - Recommended/auc: 0.4971 - loss: 3.3528 - regularization_loss: 0.0000e+00 - total_loss: 3.3528
# Epoch 10/10
# 3/3 [==============================] - 0s 81ms/step - Rating/rmse: 1.3987 - Recommended/precision: 0.8241 - Recommended/recall: 1.0000 - Recommended/accuracy: 0.8241 - Recommended/auc: 0.5005 - loss: 2.2359 - regularization_loss: 0.0000e+00 - total_loss: 2.2359

# %%
features = train_data.head()[0]

# %%
model(features)
# Out:
# {'Recommended': <tf.Tensor: shape=(10000, 1), dtype=float32, numpy=
#  array([[0.49565056],
#         [0.48492843],
#         [0.5033961 ],
#         ...,
#         [0.49643537],
#         [0.49919438],
#         [0.50095326]], dtype=float32)>,
#  'Rating': <tf.Tensor: shape=(10000, 1), dtype=float32, numpy=
#  array([[0.00747207],
#         [0.01251686],
#         [0.01540815],
#         ...,
#         [0.01885306],
#         [0.0091423 ],
#         [0.02178757]], dtype=float32)>}
